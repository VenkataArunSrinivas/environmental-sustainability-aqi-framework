# %% [markdown]
# # 02 - Cleaning and Interim EDA
#
# The provisional AQI flag is explicit because the source workbooks do not contain official AQI.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd().parent / "src"))

# %%
# %run ../scripts/run_interim_analysis.py --config ../config/project_config.yaml --allow-provisional-aqi
