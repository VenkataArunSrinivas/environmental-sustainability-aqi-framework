# %% [markdown]
# # 01 - Data Audit
#
# This notebook reproduces the source-file audit. Raw files remain unchanged.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd().parent / "src"))

# %%
# %run ../scripts/run_data_audit.py --config ../config/project_config.yaml
