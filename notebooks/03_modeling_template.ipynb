# %% [markdown]
# # 03 - Final Modeling Template
#
# Run only after the harmonized industrial and weather panel exists.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd().parent / "src"))

# %%
# %run ../scripts/build_harmonized_panel.py --config ../config/project_config.yaml

# %%
# %run ../scripts/run_baseline_models.py --config ../config/project_config.yaml
